# %% [markdown]
# <a href="https://colab.research.google.com/github/elsy-torres/script/blob/main/Grafico_sismogramas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SEÑALES SÍSMICAS

# %% [markdown]
# ## Señal sísmica registrada en las 3 componentes(V,N-S,E-W) en la estación MUR

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('MUR_Z.txt',names=['amp_v'],engine='python')
data.tail()
# Out:
#       amp_v
# 1195    433
# 1196   3032
# 1197    887
# 1198   -473
# 1199    869

# %%
data['amp_n']=pd.read_csv('MUR_N.txt')
data.head()
# Out:
#    amp_v  amp_n
# 0    526 -628.0
# 1    615 -538.0
# 2    476 -558.0
# 3    629 -477.0
# 4    556 -556.0

# %%
data['amp_e']=pd.read_csv('MUR_E.txt')

# %%
data.head()
# Out:
#    amp_v  amp_n  amp_e
# 0    526 -628.0   75.0
# 1    615 -538.0   37.0
# 2    476 -558.0  168.0
# 3    629 -477.0   23.0
# 4    556 -556.0  226.0

# %%
N=0.025
data['time']= np.arange(0,30,N)
data.head()
# Out:
#    amp_v  amp_n  amp_e   time
# 0    526 -628.0   75.0  0.000
# 1    615 -538.0   37.0  0.025
# 2    476 -558.0  168.0  0.050
# 3    629 -477.0   23.0  0.075
# 4    556 -556.0  226.0  0.100

# %%
plt.plot(data['time'],data['amp_v'])
plt.title('Estación MUR', fontsize=20,fontname='times new roman')
plt.xlabel('Tiempo (segundos)', fontsize=16,fontname='times new roman')
plt.ylabel('Desplazamiento (cuentas)', fontsize=16,fontname='times new roman')

plt.legend('V')
_ = plt.show()
# Out:
# findfont: Font family ['times new roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['times new roman'] not found. Falling back to DejaVu Sans.

# %%
plt.plot(data['time'],data['amp_n'])
plt.title('Estación MUR', fontsize=20,fontname='times new roman')
plt.xlabel('Tiempo (segundos)', fontsize=16,fontname='times new roman')
plt.ylabel('Desplazamiento (cuentas)', fontsize=16,fontname='times new roman')

plt.legend('N')
_ = plt.show()

# %%
plt.plot(data['time'],data['amp_e'])
plt.title('Estación MUR', fontsize=20,fontname='times new roman')
plt.xlabel('Tiempo (segundos)', fontsize=16,fontname='times new roman')
plt.ylabel('Desplazamiento (cuentas)', fontsize=16,fontname='times new roman')

plt.legend('E')
_ = plt.show()

# %%
fig = plt.figure(figsize=(10,10))
plt.subplot(311)
plt.plot(data['time'],data['amp_v'])
plt.title('Estación MUR', fontsize=20,fontname='times new roman')
plt.legend('Z')
plt.subplot(312)
plt.plot(data['time'],data['amp_n'])
plt.ylabel('Desplazamiento (cuentas)', fontsize=16,fontname='times new roman')
plt.legend('N')
plt.subplot(313)
plt.plot(data['time'],data['amp_e'])

plt.xlabel('Tiempo (segundos)', fontsize=16,fontname='times new roman')
plt.legend('E')

_ = plt.show()

# %% [markdown]
# ## Señal sísmica registrada en las 3 componentes en la estación PLM

# %%
data_1=pd.read_csv('PLM_Z.txt', names=['amp_v'],engine='python')
data_1.tail()
# Out:
#       amp_v
# 1195   1467
# 1196   1462
# 1197    541
# 1198    374
# 1199    188

# %%
data_1['amp_n']=pd.read_csv('PLM_N.txt')
data_1.head()
# Out:
#    amp_v   amp_n
# 0   1043  1710.0
# 1   1033  1735.0
# 2   1049  1697.0
# 3   1004  1693.0
# 4   1010  1660.0

# %%
data_1['amp_e']=pd.read_csv('PLM_E.txt')

# %%
data_1['time']= data['time']
data_1.head()
# Out:
#    amp_v   amp_n   amp_e   time
# 0   1043  1710.0  1266.0  0.000
# 1   1033  1735.0  1268.0  0.025
# 2   1049  1697.0  1238.0  0.050
# 3   1004  1693.0  1233.0  0.075
# 4   1010  1660.0  1223.0  0.100

# %%
plt.plot(data_1['time'],data_1['amp_v'])
plt.title('Estación PLM', fontsize=20,fontname='times new roman')
plt.xlabel('Tiempo (segundos)', fontsize=16,fontname='times new roman')
plt.ylabel('Desplazamiento (cuentas)', fontsize=16,fontname='times new roman')

plt.legend('V')
_ = plt.show()

# %%
plt.plot(data_1['time'],data_1['amp_n'])
plt.title('Estación PLM', fontsize=20,fontname='times new roman')
plt.xlabel('Tiempo (segundos)', fontsize=16,fontname='times new roman')
plt.ylabel('Desplazamiento (cuentas)', fontsize=16,fontname='times new roman')

plt.legend('N')
_ = plt.show()

# %%
plt.plot(data_1['time'],data_1['amp_e'])
plt.title('Estación PLM', fontsize=20,fontname='times new roman')
plt.xlabel('Tiempo (segundos)', fontsize=16,fontname='times new roman')
plt.ylabel('Desplazamiento (cuentas)', fontsize=16,fontname='times new roman')

plt.legend('E')
_ = plt.show()

# %%
fig = plt.figure(figsize=(10,10))
plt.subplot(311)
plt.plot(data_1['time'],data_1['amp_v'])
plt.title('Estación PLM', fontsize=20,fontname='times new roman')
plt.legend('Z')
plt.subplot(312)
plt.plot(data_1['time'],data_1['amp_n'])
plt.ylabel('Desplazamiento (cuentas)', fontsize=16,fontname='times new roman')
plt.legend('N')
plt.subplot(313)
plt.plot(data_1['time'],data_1['amp_e'])

plt.xlabel('Tiempo (segundos)', fontsize=16,fontname='times new roman')
plt.legend('E')

_ = plt.show()

# %% [markdown]
# ## Señal sísmica registrada en las 3 componentes en la estación SVD

# %%
data_2=pd.read_csv('SVD_Z.txt', names=['amp_v'],engine='python')
data_2.tail()
# Out:
#       amp_v
# 1195   1174
# 1196   2647
# 1197    467
# 1198  -2263
# 1199  -1356

# %%
data_2['amp_n']=pd.read_csv('SVD_N.txt')
data_2.head()
# Out:
#    amp_v   amp_n
# 0    509  -955.0
# 1    398 -1316.0
# 2    138 -1116.0
# 3    165  -776.0
# 4    270  -730.0

# %%
data_2['amp_e']=pd.read_csv('SVD_E.txt')
data_2.head()
# Out:
#    amp_v   amp_n   amp_e
# 0    509  -955.0  1618.0
# 1    398 -1316.0  1363.0
# 2    138 -1116.0  1465.0
# 3    165  -776.0  1469.0
# 4    270  -730.0  1534.0

# %%
data_2['time']=data['time']
data.head()
# Out:
#    amp_v  amp_n  amp_e   time
# 0    526 -628.0   75.0  0.000
# 1    615 -538.0   37.0  0.025
# 2    476 -558.0  168.0  0.050
# 3    629 -477.0   23.0  0.075
# 4    556 -556.0  226.0  0.100

# %%
plt.plot(data_2['time'],data_2['amp_v'])
plt.title('Estación SVD', fontsize=20,fontname='times new roman')
plt.xlabel('Tiempo (segundos)', fontsize=16,fontname='times new roman')
plt.ylabel('Desplazamiento (cuentas)', fontsize=16,fontname='times new roman')

plt.legend('V')
_ = plt.show()

# %%
plt.plot(data_2['time'],data_2['amp_n'])
plt.title('Estación SVD', fontsize=20,fontname='times new roman')
plt.xlabel('Tiempo (segundos)', fontsize=16,fontname='times new roman')
plt.ylabel('Desplazamiento (cuentas)', fontsize=16,fontname='times new roman')

plt.legend('N')
_ = plt.show()

# %%
plt.plot(data_2['time'],data_2['amp_e'])
plt.title('Estación SVD', fontsize=20,fontname='times new roman')
plt.xlabel('Tiempo (segundos)', fontsize=16,fontname='times new roman')
plt.ylabel('Desplazamiento (cuentas)', fontsize=16,fontname='times new roman')

plt.legend('E')
_ = plt.show()

# %%
fig = plt.figure(figsize=(10,10))
plt.subplot(311)
plt.plot(data_2['time'],data_2['amp_v'])
plt.title('Estación SVD', fontsize=20,fontname='times new roman')
plt.legend('Z')
plt.subplot(312)
plt.plot(data_2['time'],data_2['amp_n'])
plt.ylabel('Desplazamiento (cuentas)', fontsize=16,fontname='times new roman')
plt.legend('N')
plt.subplot(313)
plt.plot(data_2['time'],data_2['amp_e'])

plt.xlabel('Tiempo (segundos)', fontsize=16,fontname='times new roman')
plt.legend('E')

_ = plt.show()
